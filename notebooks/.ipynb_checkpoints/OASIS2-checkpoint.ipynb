# %%
import pandas as pd
import numpy as np
from pathlib import Path

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline


# -------------------------------------------------------------------
# 1. Path
# -------------------------------------------------------------------

DATA_PATH = Path("../data/OASIS2.csv")


# -------------------------------------------------------------------
# 2. Helper functions
# -------------------------------------------------------------------

def clean_column_names(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()

    rename_map = {
        "Subject ID": "subject_id",
        "MRI ID": "mri_id",
        "ID": "subject_id",
        "M/F": "sex",
        "Hand": "hand",
        "Age": "age",
        "EDUC": "education",
        "Educ": "education",
        "SES": "ses",
        "MMSE": "mmse",
        "CDR": "cdr",
        "eTIV": "etiv",
        "nWBV": "nwbv",
        "ASF": "asf",
        "Group": "group",
        "Visit": "visit",
        "MR Delay": "mr_delay"
    }

    df = df.rename(columns={col: rename_map.get(col, col) for col in df.columns})

    df.columns = (
        df.columns
        .str.strip()
        .str.lower()
        .str.replace(" ", "_")
        .str.replace("/", "_")
    )

    return df


def encode_common_variables(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()

    if "sex" in df.columns:
        df["sex"] = df["sex"].map({
            "M": 0,
            "F": 1,
            "m": 0,
            "f": 1
        })

    if "hand" in df.columns:
        df["hand"] = df["hand"].map({
            "R": 1,
            "L": 0,
            "r": 1,
            "l": 0
        })

    return df


def load_oasis2(path: Path = DATA_PATH) -> pd.DataFrame:
    df = pd.read_csv(path)
    df = clean_column_names(df)
    df = encode_common_variables(df)
    return df


# -------------------------------------------------------------------
# 3. Load OASIS-2
# -------------------------------------------------------------------

oasis2 = load_oasis2()

print(oasis2.shape)
display(oasis2.head())
print(oasis2.columns.tolist())
# Out:
# (373, 15)
#   subject_id         mri_id        group  visit  mr_delay  sex  hand  age  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0    0     1   87
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457    0     1   88
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0    0     1   75
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560    0     1   76
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895    0     1   80
#
#    education  ses  mmse  cdr         etiv      nwbv       asf
# 0         14  2.0  27.0  0.0  1986.550000  0.696106  0.883440
# 1         14  2.0  30.0  0.0  2004.479526  0.681062  0.875539
# 2         12  NaN  23.0  0.5  1678.290000  0.736336  1.045710
# 3         12  NaN  28.0  0.5  1737.620000  0.713402  1.010000
# 4         12  NaN  22.0  0.5  1697.911134  0.701236  1.033623
# ['subject_id', 'mri_id', 'group', 'visit', 'mr_delay', 'sex', 'hand', 'age', 'education', 'ses', 'mmse', 'cdr', 'etiv', 'nwbv', 'asf']

# %%
def create_oasis2_target(df: pd.DataFrame) -> pd.DataFrame:
    """
    Creates binary target:
    0 = Nondemented
    1 = Converted or Demented
    """
    df = df.copy()

    df["target"] = df["group"].map({
        "Nondemented": 0,
        "Demented": 1,
        "Converted": 1
    })

    df = df.dropna(subset=["target"])
    df["target"] = df["target"].astype(int)

    return df


def keep_first_visit(df: pd.DataFrame) -> pd.DataFrame:
    """
    Keeps the first visit per subject to avoid train-test leakage.
    """
    df = df.copy()
    df = df.sort_values(["subject_id", "visit"])
    df_first = df.groupby("subject_id", as_index=False).first()
    return df_first


oasis2 = create_oasis2_target(oasis2)
oasis2_first = keep_first_visit(oasis2)

print("Original shape:", oasis2.shape)
print("First-visit shape:", oasis2_first.shape)

print("\nOriginal group distribution:")
print(oasis2["group"].value_counts())

print("\nFirst-visit group distribution:")
print(oasis2_first["group"].value_counts())

print("\nTarget distribution:")
print(oasis2_first["target"].value_counts())
# Out:
# Original shape: (373, 16)
# First-visit shape: (150, 16)
#
# Original group distribution:
# group
# Nondemented    190
# Demented       146
# Converted       37
# Name: count, dtype: int64
#
# First-visit group distribution:
# group
# Nondemented    72
# Demented       64
# Converted      14
# Name: count, dtype: int64
#
# Target distribution:
# target
# 1    78
# 0    72
# Name: count, dtype: int64

# %%
def add_engineered_features(df):
    df = df.copy()

    # Accessible/basic feature interactions
    df["age_education"] = df["age"] * df["education"]
    df["age_ses"] = df["age"] * df["ses"]

    # Anatomical/medical-style interactions
    df["age_nwbv"] = df["age"] * df["nwbv"]
    df["etiv_asf"] = df["etiv"] * df["asf"]

    return df


oasis2_first = add_engineered_features(oasis2_first)

# %%
# Check missing values in the first-visit dataset
missing = oasis2_first.isna().sum().sort_values(ascending=False)
missing_pct = (oasis2_first.isna().mean() * 100).sort_values(ascending=False)

missing_summary = pd.DataFrame({
    "missing_count": missing,
    "missing_percentage": missing_pct
})

display(missing_summary)
# Out:
#                missing_count  missing_percentage
# age_ses                    8            5.333333
# ses                        8            5.333333
# subject_id                 0            0.000000
# mri_id                     0            0.000000
# visit                      0            0.000000
# group                      0            0.000000
# hand                       0            0.000000
# mr_delay                   0            0.000000
# age                        0            0.000000
# education                  0            0.000000
# mmse                       0            0.000000
# sex                        0            0.000000
# cdr                        0            0.000000
# etiv                       0            0.000000
# asf                        0            0.000000
# nwbv                       0            0.000000
# target                     0            0.000000
# age_education              0            0.000000
# age_nwbv                   0            0.000000
# etiv_asf                   0            0.000000

# %%
FEATURE_SETS = {
    "FS1_accessible": [
        "age", "sex", "education", "ses", "hand",
        "age_education", "age_ses"
    ],

    "FS2_accessible_anatomical": [
        "age", "sex", "education", "ses", "hand",
        "age_education", "age_ses",
        "etiv", "nwbv", "asf",
        "age_nwbv", "etiv_asf"
    ],

    "FS3_accessible_anatomical_cognitive": [
        "age", "sex", "education", "ses", "hand",
        "age_education", "age_ses",
        "etiv", "nwbv", "asf",
        "age_nwbv", "etiv_asf",
        "mmse"
    ]
}

train_df, test_df = train_test_split(
    oasis2_first,
    test_size=0.20,
    random_state=42,
    stratify=oasis2_first["target"]
)

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)

print("\nTrain target distribution:")
print(train_df["target"].value_counts())

print("\nTest target distribution:")
print(test_df["target"].value_counts())
# Out:
# Train shape: (120, 20)
# Test shape: (30, 20)
#
# Train target distribution:
# target
# 1    62
# 0    58
# Name: count, dtype: int64
#
# Test target distribution:
# target
# 1    16
# 0    14
# Name: count, dtype: int64

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

def build_preprocessor(features, scale=True):
    if scale:
        numeric_pipeline = Pipeline([
            ("imputer", SimpleImputer(strategy="median")),
            ("scaler", StandardScaler())
        ])
    else:
        numeric_pipeline = Pipeline([
            ("imputer", SimpleImputer(strategy="median"))
        ])

    return ColumnTransformer([
        ("numeric", numeric_pipeline, features)
    ])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

model_grids = {
    "Logistic Regression": {
        "model": LogisticRegression(
            max_iter=5000,
            class_weight="balanced",
            solver="liblinear"
        ),
        "scale": True,
        "params": {
            "model__C": [0.01, 0.1, 1, 10],
            "model__penalty": ["l1", "l2"]
        }
    },

    "Random Forest": {
        "model": RandomForestClassifier(
            random_state=42,
            class_weight="balanced"
        ),
        "scale": False,
        "params": {
            "model__n_estimators": [100, 300, 500],
            "model__max_depth": [None, 3, 5, 10],
            "model__min_samples_leaf": [1, 2, 4],
            "model__max_features": ["sqrt", "log2"]
        }
    },

    "XGBoost": {
        "model": XGBClassifier(
            random_state=42,
            eval_metric="logloss",
            n_jobs=-1
        ),
        "scale": False,
        "params": {
            "model__n_estimators": [50, 100, 300],
            "model__learning_rate": [0.01, 0.05, 0.1],
            "model__max_depth": [2, 3, 4],
            "model__subsample": [0.8, 1.0],
            "model__colsample_bytree": [0.8, 1.0],
            "model__reg_lambda": [1, 5, 10]
        }
    }
}

# %%
from sklearn.metrics import (
    roc_auc_score,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

results = []
trained_models = {}

for feature_set_name, features in FEATURE_SETS.items():
    X_train = train_df[features]
    y_train = train_df["target"]

    X_test = test_df[features]
    y_test = test_df["target"]

    for model_name, model_info in model_grids.items():

        preprocessor = build_preprocessor(
            features=features,
            scale=model_info["scale"]
        )

        pipeline = Pipeline([
            ("preprocessor", preprocessor),
            ("model", model_info["model"])
        ])

        grid = GridSearchCV(
            estimator=pipeline,
            param_grid=model_info["params"],
            scoring="roc_auc",
            cv=cv,
            n_jobs=-1,
            refit=True
        )

        grid.fit(X_train, y_train)

        best_model = grid.best_estimator_

        y_pred = best_model.predict(X_test)
        y_proba = best_model.predict_proba(X_test)[:, 1]

        results.append({
            "feature_set": feature_set_name,
            "model": model_name,
            "best_cv_auc": grid.best_score_,
            "test_roc_auc": roc_auc_score(y_test, y_proba),
            "accuracy": accuracy_score(y_test, y_pred),
            "precision": precision_score(y_test, y_pred, zero_division=0),
            "recall": recall_score(y_test, y_pred, zero_division=0),
            "f1": f1_score(y_test, y_pred, zero_division=0),
            "best_params": grid.best_params_
        })

        trained_models[(feature_set_name, model_name)] = best_model

        print(f"Finished: {feature_set_name} - {model_name}")
        print("Best CV AUC:", round(grid.best_score_, 3))
        print("Test AUC:", round(roc_auc_score(y_test, y_proba), 3))
        print("Best params:", grid.best_params_)
        print()
# Out:
# Finished: FS1_accessible - Logistic Regression
# Best CV AUC: 0.663
# Test AUC: 0.629
# Best params: {'model__C': 1, 'model__penalty': 'l1'}
#
# Finished: FS1_accessible - Random Forest
# Best CV AUC: 0.637
# Test AUC: 0.625
# Best params: {'model__max_depth': 3, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 4, 'model__n_estimators': 500}
#
# Finished: FS1_accessible - XGBoost
# Best CV AUC: 0.688
# Test AUC: 0.665
# Best params: {'model__colsample_bytree': 1.0, 'model__learning_rate': 0.01, 'model__max_depth': 2, 'model__n_estimators': 300, 'model__reg_lambda': 10, 'model__subsample': 1.0}
#
# Finished: FS2_accessible_anatomical - Logistic Regression
# Best CV AUC: 0.728
# Test AUC: 0.652
# Best params: {'model__C': 1, 'model__penalty': 'l1'}
#
# Finished: FS2_accessible_anatomical - Random Forest
# Best CV AUC: 0.724
# Test AUC: 0.692
# Best params: {'model__max_depth': None, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 2, 'model__n_estimators': 500}
#
# Finished: FS2_accessible_anatomical - XGBoost
# Best CV AUC: 0.741
# Test AUC: 0.812
# Best params: {'model__colsample_bytree': 0.8, 'model__learning_rate': 0.1, 'model__max_depth': 3, 'model__n_estimators': 300, 'model__reg_lambda': 10, 'model__subsample': 0.8}
#
# Finished: FS3_accessible_anatomical_cognitive - Logistic Regression
# Best CV AUC: 0.84
# Test AUC: 0.754
# Best params: {'model__C': 1, 'model__penalty': 'l2'}
#
# Finished: FS3_accessible_anatomical_cognitive - Random Forest
# Best CV AUC: 0.873
# Test AUC: 0.79
# Best params: {'model__max_depth': None, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 4, 'model__n_estimators': 500}
#
# Finished: FS3_accessible_anatomical_cognitive - XGBoost
# Best CV AUC: 0.88
# Test AUC: 0.777
# Best params: {'model__colsample_bytree': 0.8, 'model__learning_rate': 0.05, 'model__max_depth': 4, 'model__n_estimators': 100, 'model__reg_lambda': 1, 'model__subsample': 0.8}

# %%
results_df = pd.DataFrame(results)

results_df = results_df.sort_values(
    by=["feature_set", "test_roc_auc"],
    ascending=[True, False]
).reset_index(drop=True)

metric_cols = [
    "best_cv_auc", "test_roc_auc",
    "accuracy", "precision", "recall", "f1"
]

results_table = results_df.copy()
results_table[metric_cols] = results_table[metric_cols].round(3)

display(results_table)
# Out:
#                            feature_set                model  best_cv_auc  \
# 0                       FS1_accessible              XGBoost        0.688
# 1                       FS1_accessible  Logistic Regression        0.663
# 2                       FS1_accessible        Random Forest        0.637
# 3            FS2_accessible_anatomical              XGBoost        0.741
# 4            FS2_accessible_anatomical        Random Forest        0.724
# 5            FS2_accessible_anatomical  Logistic Regression        0.728
# 6  FS3_accessible_anatomical_cognitive        Random Forest        0.873
# 7  FS3_accessible_anatomical_cognitive              XGBoost        0.880
# 8  FS3_accessible_anatomical_cognitive  Logistic Regression        0.840
#
#    test_roc_auc  accuracy  precision  recall     f1  \
# 0         0.665     0.600      0.643   0.562  0.600
# 1         0.629     0.533      0.571   0.500  0.533
# 2         0.625     0.500      0.533   0.500  0.516
# 3         0.812     0.733      0.833   0.625  0.714
# 4         0.692     0.600      0.700   0.438  0.538
# 5         0.652     0.600      0.625   0.625  0.625
# 6         0.790     0.700      0.818   0.562  0.667
# 7         0.777     0.733      0.900   0.562  0.692
# 8         0.754     0.667      0.800   0.500  0.615
#
#                                          best_params
# 0  {'model__colsample_bytree': 1.0, 'model__learn...
# 1            {'model__C': 1, 'model__penalty': 'l1'}
# 2  {'model__max_depth': 3, 'model__max_features':...
# 3  {'model__colsample_bytree': 0.8, 'model__learn...
# 4  {'model__max_depth': None, 'model__max_feature...
# 5            {'model__C': 1, 'model__penalty': 'l1'}
# 6  {'model__max_depth': None, 'model__max_feature...
# 7  {'model__colsample_bytree': 0.8, 'model__learn...
# 8            {'model__C': 1, 'model__penalty': 'l2'}

# %%
from pathlib import Path

Path("../results").mkdir(exist_ok=True)

results_table.to_csv("../results/oasis2_tuned_model_results.csv", index=False)

display(results_table)
# Out:
#                            feature_set                model  best_cv_auc  \
# 0                       FS1_accessible              XGBoost        0.688
# 1                       FS1_accessible  Logistic Regression        0.663
# 2                       FS1_accessible        Random Forest        0.637
# 3            FS2_accessible_anatomical              XGBoost        0.741
# 4            FS2_accessible_anatomical        Random Forest        0.724
# 5            FS2_accessible_anatomical  Logistic Regression        0.728
# 6  FS3_accessible_anatomical_cognitive        Random Forest        0.873
# 7  FS3_accessible_anatomical_cognitive              XGBoost        0.880
# 8  FS3_accessible_anatomical_cognitive  Logistic Regression        0.840
#
#    test_roc_auc  accuracy  precision  recall     f1  \
# 0         0.665     0.600      0.643   0.562  0.600
# 1         0.629     0.533      0.571   0.500  0.533
# 2         0.625     0.500      0.533   0.500  0.516
# 3         0.812     0.733      0.833   0.625  0.714
# 4         0.692     0.600      0.700   0.438  0.538
# 5         0.652     0.600      0.625   0.625  0.625
# 6         0.790     0.700      0.818   0.562  0.667
# 7         0.777     0.733      0.900   0.562  0.692
# 8         0.754     0.667      0.800   0.500  0.615
#
#                                          best_params
# 0  {'model__colsample_bytree': 1.0, 'model__learn...
# 1            {'model__C': 1, 'model__penalty': 'l1'}
# 2  {'model__max_depth': 3, 'model__max_features':...
# 3  {'model__colsample_bytree': 0.8, 'model__learn...
# 4  {'model__max_depth': None, 'model__max_feature...
# 5            {'model__C': 1, 'model__penalty': 'l1'}
# 6  {'model__max_depth': None, 'model__max_feature...
# 7  {'model__colsample_bytree': 0.8, 'model__learn...
# 8            {'model__C': 1, 'model__penalty': 'l2'}

# %%
from sklearn.model_selection import RepeatedStratifiedKFold, cross_val_score
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np

repeated_cv = RepeatedStratifiedKFold(
    n_splits=5,
    n_repeats=10,
    random_state=42
)

cv_summary = []

for feature_set_name, features in FEATURE_SETS.items():
    X = oasis2_first[features]
    y = oasis2_first["target"]

    for model_name, model_info in model_grids.items():
        preprocessor = build_preprocessor(
            features=features,
            scale=model_info["scale"]
        )

        pipeline = Pipeline([
            ("preprocessor", preprocessor),
            ("model", model_info["model"])
        ])

        scores = cross_val_score(
            pipeline,
            X,
            y,
            scoring="roc_auc",
            cv=repeated_cv,
            n_jobs=-1
        )

        cv_summary.append({
            "feature_set": feature_set_name,
            "model": model_name,
            "mean_auc": scores.mean(),
            "std_auc": scores.std(),
            "min_auc": scores.min(),
            "max_auc": scores.max()
        })

cv_summary_df = pd.DataFrame(cv_summary)

cv_summary_table = cv_summary_df.copy()
cv_summary_table[["mean_auc", "std_auc", "min_auc", "max_auc"]] = (
    cv_summary_table[["mean_auc", "std_auc", "min_auc", "max_auc"]].round(3)
)

cv_summary_table = cv_summary_table.sort_values(
    by=["feature_set", "mean_auc"],
    ascending=[True, False]
).reset_index(drop=True)

display(cv_summary_table)

cv_summary_table.to_csv("../results/oasis2_repeated_cv_results.csv", index=False)
# Out:
#                            feature_set                model  mean_auc  \
# 0                       FS1_accessible  Logistic Regression     0.646
# 1                       FS1_accessible              XGBoost     0.619
# 2                       FS1_accessible        Random Forest     0.596
# 3            FS2_accessible_anatomical              XGBoost     0.722
# 4            FS2_accessible_anatomical        Random Forest     0.705
# 5            FS2_accessible_anatomical  Logistic Regression     0.703
# 6  FS3_accessible_anatomical_cognitive        Random Forest     0.835
# 7  FS3_accessible_anatomical_cognitive              XGBoost     0.835
# 8  FS3_accessible_anatomical_cognitive  Logistic Regression     0.829
#
#    std_auc  min_auc  max_auc
# 0    0.094    0.411    0.831
# 1    0.066    0.471    0.801
# 2    0.062    0.382    0.737
# 3    0.069    0.554    0.880
# 4    0.079    0.520    0.873
# 5    0.079    0.513    0.880
# 6    0.066    0.629    0.978
# 7    0.066    0.661    0.955
# 8    0.066    0.679    1.000

# %%
BEST_MODELS = {
    "FS1_accessible": "XGBoost",
    "FS2_accessible_anatomical": "XGBoost",
    "FS3_accessible_anatomical_cognitive": "Random Forest"
}

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from pathlib import Path

Path("../results").mkdir(exist_ok=True)

for feature_set_name, model_name in BEST_MODELS.items():
    model = trained_models[(feature_set_name, model_name)]
    features = FEATURE_SETS[feature_set_name]

    X_test = test_df[features]
    y_test = test_df["target"]
    y_pred = model.predict(X_test)

    cm = confusion_matrix(y_test, y_pred)

    disp = ConfusionMatrixDisplay(
        confusion_matrix=cm,
        display_labels=["Nondemented", "Demented/Converted"]
    )

    disp.plot()
    plt.title(f"{feature_set_name} - {model_name}")
    plt.tight_layout()

    filename = f"../results/confusion_matrix_{feature_set_name}_{model_name}.png"
    filename = filename.replace(" ", "_")

    plt.savefig(filename, dpi=300, bbox_inches="tight")
    plt.show()

# %%
def plot_feature_importance(feature_set_name, model_name):
    model = trained_models[(feature_set_name, model_name)]
    features = FEATURE_SETS[feature_set_name]

    fitted_model = model.named_steps["model"]

    if hasattr(fitted_model, "feature_importances_"):
        importances = fitted_model.feature_importances_
        importance_type = "Feature importance"
    elif hasattr(fitted_model, "coef_"):
        importances = abs(fitted_model.coef_[0])
        importance_type = "Absolute standardized coefficient"
    else:
        print(f"{model_name} has no built-in feature importance.")
        return None

    importance_df = pd.DataFrame({
        "feature": features,
        "importance": importances
    }).sort_values("importance", ascending=True)

    plt.figure(figsize=(10, 7))
    plt.barh(importance_df["feature"], importance_df["importance"])
    plt.xlabel(importance_type)
    plt.title(f"{feature_set_name} - {model_name}")
    plt.tight_layout()

    filename = f"../results/feature_importance_{feature_set_name}_{model_name}.png"
    filename = filename.replace(" ", "_")
    plt.savefig(filename, dpi=300, bbox_inches="tight")
    plt.show()

    return importance_df.sort_values("importance", ascending=False)

# %%
fi_fs1 = plot_feature_importance("FS1_accessible", "Logistic Regression")
fi_fs2 = plot_feature_importance("FS2_accessible_anatomical", "XGBoost")
fi_fs3 = plot_feature_importance("FS3_accessible_anatomical_cognitive", "Random Forest")

# %%
from sklearn.metrics import accuracy_score, recall_score, roc_auc_score, confusion_matrix
import numpy as np
import pandas as pd

def false_positive_rate(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()
    return fp / (fp + tn) if (fp + tn) > 0 else np.nan

def compute_group_fairness(model, X, y, group_values, group_name):
    y_pred = model.predict(X)
    y_proba = model.predict_proba(X)[:, 1]
    
    rows = []
    
    for group in sorted(group_values.dropna().unique()):
        mask = group_values == group
        
        y_group = y[mask]
        pred_group = y_pred[mask]
        proba_group = y_proba[mask]
        
        if len(y_group) == 0:
            continue
        
        if len(np.unique(y_group)) > 1:
            group_auc = roc_auc_score(y_group, proba_group)
        else:
            group_auc = np.nan
        
        rows.append({
            "group_variable": group_name,
            "group": group,
            "n": len(y_group),
            "positive_prediction_rate": np.mean(pred_group),
            "accuracy": accuracy_score(y_group, pred_group),
            "recall_tpr": recall_score(y_group, pred_group, zero_division=0),
            "false_positive_rate": false_positive_rate(y_group, pred_group),
            "roc_auc": group_auc
        })
    
    return pd.DataFrame(rows)

# %%
test_df = test_df.copy()

test_df["age_group"] = pd.cut(
    test_df["age"],
    bins=[0, 75, 120],
    labels=["<75", "75+"]
)

print(test_df["age_group"].value_counts())
print(test_df["sex"].value_counts())
# Out:
# age_group
# 75+    16
# <75    14
# Name: count, dtype: int64
# sex
# 0    16
# 1    14
# Name: count, dtype: int64

# %%
fairness_results = []

for feature_set_name, model_name in BEST_MODELS.items():
    model = trained_models[(feature_set_name, model_name)]
    features = FEATURE_SETS[feature_set_name]

    X_test = test_df[features]
    y_test = test_df["target"]

    sex_fairness = compute_group_fairness(
        model=model,
        X=X_test,
        y=y_test,
        group_values=test_df["sex"],
        group_name="sex"
    )

    age_fairness = compute_group_fairness(
        model=model,
        X=X_test,
        y=y_test,
        group_values=test_df["age_group"],
        group_name="age_group"
    )

    combined = pd.concat([sex_fairness, age_fairness], ignore_index=True)
    combined.insert(0, "feature_set", feature_set_name)
    combined.insert(1, "model", model_name)

    fairness_results.append(combined)

fairness_results_df = pd.concat(fairness_results, ignore_index=True)

fairness_results_table = fairness_results_df.copy()

numeric_cols = [
    "positive_prediction_rate",
    "accuracy",
    "recall_tpr",
    "false_positive_rate",
    "roc_auc"
]

fairness_results_table[numeric_cols] = fairness_results_table[numeric_cols].round(3)

display(fairness_results_table)

fairness_results_table.to_csv(
    "../results/oasis2_fairness_results.csv",
    index=False
)
# Out:
#                             feature_set          model group_variable group  \
# 0                        FS1_accessible        XGBoost            sex     0
# 1                        FS1_accessible        XGBoost            sex     1
# 2                        FS1_accessible        XGBoost      age_group   75+
# 3                        FS1_accessible        XGBoost      age_group   <75
# 4             FS2_accessible_anatomical        XGBoost            sex     0
# 5             FS2_accessible_anatomical        XGBoost            sex     1
# 6             FS2_accessible_anatomical        XGBoost      age_group   75+
# 7             FS2_accessible_anatomical        XGBoost      age_group   <75
# 8   FS3_accessible_anatomical_cognitive  Random Forest            sex     0
# 9   FS3_accessible_anatomical_cognitive  Random Forest            sex     1
# 10  FS3_accessible_anatomical_cognitive  Random Forest      age_group   75+
# 11  FS3_accessible_anatomical_cognitive  Random Forest      age_group   <75
#
#      n  positive_prediction_rate  accuracy  recall_tpr  false_positive_rate  \
# 0   16                     0.750     0.562       0.727                0.800
# 1   14                     0.143     0.643       0.200                0.111
# 2   16                     0.375     0.562       0.444                0.286
# 3   14                     0.571     0.643       0.714                0.429
# 4   16                     0.562     0.625       0.636                0.400
# 5   14                     0.214     0.857       0.600                0.000
# 6   16                     0.562     0.750       0.778                0.286
# 7   14                     0.214     0.714       0.429                0.000
# 8   16                     0.438     0.625       0.545                0.200
# 9   14                     0.286     0.786       0.600                0.111
# 10  16                     0.438     0.750       0.667                0.143
# 11  14                     0.286     0.643       0.429                0.143
#
#     roc_auc
# 0     0.473
# 1     0.644
# 2     0.563
# 3     0.796
# 4     0.673
# 5     0.889
# 6     0.794
# 7     0.857
# 8     0.691
# 9     0.822
# 10    0.857
# 11    0.755

# %%
fairness_gap_rows = []

for (feature_set, model, group_variable), group_df in fairness_results_df.groupby(
    ["feature_set", "model", "group_variable"]
):
    fairness_gap_rows.append({
        "feature_set": feature_set,
        "model": model,
        "group_variable": group_variable,
        "positive_prediction_rate_gap": (
            group_df["positive_prediction_rate"].max()
            - group_df["positive_prediction_rate"].min()
        ),
        "recall_tpr_gap": (
            group_df["recall_tpr"].max()
            - group_df["recall_tpr"].min()
        ),
        "false_positive_rate_gap": (
            group_df["false_positive_rate"].max()
            - group_df["false_positive_rate"].min()
        )
    })

fairness_gap_df = pd.DataFrame(fairness_gap_rows)
fairness_gap_table = fairness_gap_df.round(3)

display(fairness_gap_table)

fairness_gap_table.to_csv(
    "../results/oasis2_fairness_gap_summary.csv",
    index=False
)
# Out:
#                            feature_set          model group_variable  \
# 0                       FS1_accessible        XGBoost      age_group
# 1                       FS1_accessible        XGBoost            sex
# 2            FS2_accessible_anatomical        XGBoost      age_group
# 3            FS2_accessible_anatomical        XGBoost            sex
# 4  FS3_accessible_anatomical_cognitive  Random Forest      age_group
# 5  FS3_accessible_anatomical_cognitive  Random Forest            sex
#
#    positive_prediction_rate_gap  recall_tpr_gap  false_positive_rate_gap
# 0                         0.196           0.270                    0.143
# 1                         0.607           0.527                    0.689
# 2                         0.348           0.349                    0.286
# 3                         0.348           0.036                    0.400
# 4                         0.152           0.238                    0.000
# 5                         0.152           0.055                    0.089

# %%
import shap
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path

Path("../results").mkdir(exist_ok=True)

# %%
def get_transformed_test_data(model, X_test, features):
    preprocessor = model.named_steps["preprocessor"]
    X_processed = preprocessor.transform(X_test)

    return pd.DataFrame(
        X_processed,
        columns=features,
        index=X_test.index
    )

# %%
shap_importance_results = []

for feature_set_name, model_name in BEST_MODELS.items():
    print(f"Running SHAP for {feature_set_name} - {model_name}")

    model = trained_models[(feature_set_name, model_name)]
    features = FEATURE_SETS[feature_set_name]

    X_test = test_df[features]
    X_test_processed = get_transformed_test_data(model, X_test, features)

    fitted_model = model.named_steps["model"]

    explainer = shap.Explainer(fitted_model, X_test_processed)
    shap_values = explainer(X_test_processed)

    values = shap_values.values

    # Some binary classifiers return SHAP values with shape:
    # samples x features x classes
    if values.ndim == 3:
        values = values[:, :, 1]

    mean_abs_shap = np.abs(values).mean(axis=0)

    shap_importance_df = pd.DataFrame({
        "feature_set": feature_set_name,
        "model": model_name,
        "feature": features,
        "mean_abs_shap": mean_abs_shap
    }).sort_values("mean_abs_shap", ascending=False)

    shap_importance_results.append(shap_importance_df)

shap_importance_all = pd.concat(shap_importance_results, ignore_index=True)
shap_importance_table = shap_importance_all.copy()
shap_importance_table["mean_abs_shap"] = shap_importance_table["mean_abs_shap"].round(4)

display(shap_importance_table)

shap_importance_table.to_csv(
    "../results/oasis2_shap_importance.csv",
    index=False
)
# Out:
# Running SHAP for FS1_accessible - XGBoost
# Running SHAP for FS2_accessible_anatomical - XGBoost
# Running SHAP for FS3_accessible_anatomical_cognitive - Random Forest
#                             feature_set          model        feature  \
# 0                        FS1_accessible        XGBoost  age_education
# 1                        FS1_accessible        XGBoost            sex
# 2                        FS1_accessible        XGBoost      education
# 3                        FS1_accessible        XGBoost        age_ses
# 4                        FS1_accessible        XGBoost            age
# 5                        FS1_accessible        XGBoost           hand
# 6                        FS1_accessible        XGBoost            ses
# 7             FS2_accessible_anatomical        XGBoost       etiv_asf
# 8             FS2_accessible_anatomical        XGBoost  age_education
# 9             FS2_accessible_anatomical        XGBoost           nwbv
# 10            FS2_accessible_anatomical        XGBoost            sex
# 11            FS2_accessible_anatomical        XGBoost        age_ses
# 12            FS2_accessible_anatomical        XGBoost      education
# 13            FS2_accessible_anatomical        XGBoost           etiv
# 14            FS2_accessible_anatomical        XGBoost       age_nwbv
# 15            FS2_accessible_anatomical        XGBoost            ses
# 16            FS2_accessible_anatomical        XGBoost            age
# 17            FS2_accessible_anatomical        XGBoost            asf
# 18            FS2_accessible_anatomical        XGBoost           hand
# 19  FS3_accessible_anatomical_cognitive  Random Forest           mmse
# 20  FS3_accessible_anatomical_cognitive  Random Forest           nwbv
# 21  FS3_accessible_anatomical_cognitive  Random Forest       etiv_asf
# 22  FS3_accessible_anatomical_cognitive  Random Forest  age_education
# 23  FS3_accessible_anatomical_cognitive  Random Forest      education
# 24  FS3_accessible_anatomical_cognitive  Random Forest       age_nwbv
# 25  FS3_accessible_anatomical_cognitive  Random Forest            sex
# 26  FS3_accessible_anatomical_cognitive  Random Forest            asf
# 27  FS3_accessible_anatomical_cognitive  Random Forest           etiv
# 28  FS3_accessible_anatomical_cognitive  Random Forest        age_ses
# 29  FS3_accessible_anatomical_cognitive  Random Forest            age
# 30  FS3_accessible_anatomical_cognitive  Random Forest            ses
# 31  FS3_accessible_anatomical_cognitive  Random Forest           hand
#
#     mean_abs_shap
# 0          0.4006
# 1          0.2331
# 2          0.1136
# 3          0.1048
# 4          0.0585
# 5          0.0000
# 6          0.0000
# 7          0.7160
# 8          0.6376
# 9          0.5623
# 10         0.4110
# 11         0.3276
# 12         0.2821
# 13         0.2597
# 14         0.1988
# 15         0.1317
# 16         0.1059
# 17         0.0910
# 18         0.0000
# 19         0.1308
# 20         0.0431
# 21         0.0414
# 22         0.0362
# 23         0.0278
# 24         0.0212
# 25         0.0166
# 26         0.0157
# 27         0.0156
# 28         0.0126
# 29         0.0065
# 30         0.0050
# 31         0.0000

# %%
for feature_set_name, model_name in BEST_MODELS.items():
    print(f"Creating SHAP bar plot for {feature_set_name} - {model_name}")

    shap_subset = shap_importance_all[
        (shap_importance_all["feature_set"] == feature_set_name)
        & (shap_importance_all["model"] == model_name)
    ].sort_values("mean_abs_shap", ascending=True)

    plt.figure(figsize=(4, 3))
    plt.barh(shap_subset["feature"], shap_subset["mean_abs_shap"])
    plt.xlabel("Mean absolute SHAP value")
    plt.title(f"SHAP importance: {feature_set_name} - {model_name}")
    plt.tight_layout()

    filename = f"../results/shap_importance_{feature_set_name}_{model_name}.png"
    filename = filename.replace(" ", "_")

    plt.savefig(filename, dpi=300, bbox_inches="tight")
    plt.show()
# Out:
# Creating SHAP bar plot for FS1_accessible - XGBoost
# Creating SHAP bar plot for FS2_accessible_anatomical - XGBoost
# Creating SHAP bar plot for FS3_accessible_anatomical_cognitive - Random Forest

# %%
from pathlib import Path

results_dir = Path("../results")

output_files = sorted([file.name for file in results_dir.iterdir()])

print("Saved output files:")
for file in output_files:
    print("-", file)
# Out:
# Saved output files:
# - confusion_matrix_FS1_accessible_Logistic_Regression.png
# - confusion_matrix_FS1_accessible_XGBoost.png
# - confusion_matrix_FS2_accessible_anatomical_XGBoost.png
# - confusion_matrix_FS3_accessible_anatomical_cognitive_Random_Forest.png
# - feature_importance_FS1_accessible_Logistic_Regression.png
# - feature_importance_FS2_accessible_anatomical_XGBoost.png
# - feature_importance_FS3_accessible_anatomical_cognitive_Random_Forest.png
# - feature_importance_fs1_logistic_regression.csv
# - feature_importance_fs2_xgboost.csv
# - feature_importance_fs3_random_forest.csv
# - oasis2_fairness_gap_summary.csv
# - oasis2_fairness_results.csv
# - oasis2_repeated_cv_results.csv
# - oasis2_shap_importance.csv
# - oasis2_tuned_model_results.csv
# - shap_importance_FS1_accessible_XGBoost.png
# - shap_importance_FS2_accessible_anatomical_XGBoost.png
# - shap_importance_FS3_accessible_anatomical_cognitive_Random_Forest.png

# %% [markdown]
# **OASIS1 ROBUSTNESS CHECK**

# %%
OASIS1_PATH = Path("../data/OASIS1.csv")

oasis1 = pd.read_csv(OASIS1_PATH)

print(oasis1.shape)
display(oasis1.head())
print(oasis1.columns.tolist())
# Out:
# (436, 12)
#               ID M/F Hand  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF  \
# 0  OAS1_0001_MR1   F    R   74   2.0  3.0  29.0  0.0  1344  0.743  1.306
# 1  OAS1_0002_MR1   F    R   55   4.0  1.0  29.0  0.0  1147  0.810  1.531
# 2  OAS1_0003_MR1   F    R   73   4.0  3.0  27.0  0.5  1454  0.708  1.207
# 3  OAS1_0004_MR1   M    R   28   NaN  NaN   NaN  NaN  1588  0.803  1.105
# 4  OAS1_0005_MR1   M    R   18   NaN  NaN   NaN  NaN  1737  0.848  1.010
#
#    Delay
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ['ID', 'M/F', 'Hand', 'Age', 'Educ', 'SES', 'MMSE', 'CDR', 'eTIV', 'nWBV', 'ASF', 'Delay']

# %%
oasis1 = clean_column_names(oasis1)
oasis1 = encode_common_variables(oasis1)

print(oasis1.shape)
display(oasis1.head())
print(oasis1.columns.tolist())
# Out:
# (436, 12)
#       subject_id  sex  hand  age  education  ses  mmse  cdr  etiv   nwbv  \
# 0  OAS1_0001_MR1    1     1   74        2.0  3.0  29.0  0.0  1344  0.743
# 1  OAS1_0002_MR1    1     1   55        4.0  1.0  29.0  0.0  1147  0.810
# 2  OAS1_0003_MR1    1     1   73        4.0  3.0  27.0  0.5  1454  0.708
# 3  OAS1_0004_MR1    0     1   28        NaN  NaN   NaN  NaN  1588  0.803
# 4  OAS1_0005_MR1    0     1   18        NaN  NaN   NaN  NaN  1737  0.848
#
#      asf  delay
# 0  1.306    NaN
# 1  1.531    NaN
# 2  1.207    NaN
# 3  1.105    NaN
# 4  1.010    NaN
# ['subject_id', 'sex', 'hand', 'age', 'education', 'ses', 'mmse', 'cdr', 'etiv', 'nwbv', 'asf', 'delay']

# %%
def create_oasis1_target_from_cdr(df: pd.DataFrame) -> pd.DataFrame:
    """
    Creates binary target for OASIS-1 based on CDR:
    0 = CDR 0.0
    1 = CDR > 0.0
    """
    df = df.copy()

    df = df.dropna(subset=["cdr"])
    df["target"] = (df["cdr"] > 0).astype(int)

    return df


oasis1 = create_oasis1_target_from_cdr(oasis1)

print(oasis1.shape)
print(oasis1["target"].value_counts())
print(oasis1["cdr"].value_counts().sort_index())
display(oasis1.head())
# Out:
# (235, 13)
# target
# 0    135
# 1    100
# Name: count, dtype: int64
# cdr
# 0.0    135
# 0.5     70
# 1.0     28
# 2.0      2
# Name: count, dtype: int64
#       subject_id  sex  hand  age  education  ses  mmse  cdr  etiv   nwbv  \
# 0  OAS1_0001_MR1    1     1   74        2.0  3.0  29.0  0.0  1344  0.743
# 1  OAS1_0002_MR1    1     1   55        4.0  1.0  29.0  0.0  1147  0.810
# 2  OAS1_0003_MR1    1     1   73        4.0  3.0  27.0  0.5  1454  0.708
# 8  OAS1_0010_MR1    0     1   74        5.0  2.0  30.0  0.0  1636  0.689
# 9  OAS1_0011_MR1    1     1   52        3.0  2.0  30.0  0.0  1321  0.827
#
#      asf  delay  target
# 0  1.306    NaN       0
# 1  1.531    NaN       0
# 2  1.207    NaN       1
# 8  1.073    NaN       0
# 9  1.329    NaN       0

# %%
oasis1 = add_engineered_features(oasis1)

print(oasis1.shape)
print(oasis1.columns.tolist())
display(oasis1.head())
# Out:
# (235, 17)
# ['subject_id', 'sex', 'hand', 'age', 'education', 'ses', 'mmse', 'cdr', 'etiv', 'nwbv', 'asf', 'delay', 'target', 'age_education', 'age_ses', 'age_nwbv', 'etiv_asf']
#       subject_id  sex  hand  age  education  ses  mmse  cdr  etiv   nwbv  \
# 0  OAS1_0001_MR1    1     1   74        2.0  3.0  29.0  0.0  1344  0.743
# 1  OAS1_0002_MR1    1     1   55        4.0  1.0  29.0  0.0  1147  0.810
# 2  OAS1_0003_MR1    1     1   73        4.0  3.0  27.0  0.5  1454  0.708
# 8  OAS1_0010_MR1    0     1   74        5.0  2.0  30.0  0.0  1636  0.689
# 9  OAS1_0011_MR1    1     1   52        3.0  2.0  30.0  0.0  1321  0.827
#
#      asf  delay  target  age_education  age_ses  age_nwbv  etiv_asf
# 0  1.306    NaN       0          148.0    222.0    54.982  1755.264
# 1  1.531    NaN       0          220.0     55.0    44.550  1756.057
# 2  1.207    NaN       1          292.0    219.0    51.684  1754.978
# 8  1.073    NaN       0          370.0    148.0    50.986  1755.428
# 9  1.329    NaN       0          156.0    104.0    43.004  1755.609

# %%
for feature_set_name, features in FEATURE_SETS.items():
    missing_features = [feature for feature in features if feature not in oasis1.columns]
    available_features = [feature for feature in features if feature in oasis1.columns]

    print(f"\n{feature_set_name}")
    print("Available:", available_features)
    print("Missing:", missing_features)
# Out:
# FS1_accessible
# Available: ['age', 'sex', 'education', 'ses', 'hand', 'age_education', 'age_ses']
# Missing: []
#
# FS2_accessible_anatomical
# Available: ['age', 'sex', 'education', 'ses', 'hand', 'age_education', 'age_ses', 'etiv', 'nwbv', 'asf', 'age_nwbv', 'etiv_asf']
# Missing: []
#
# FS3_accessible_anatomical_cognitive
# Available: ['age', 'sex', 'education', 'ses', 'hand', 'age_education', 'age_ses', 'etiv', 'nwbv', 'asf', 'age_nwbv', 'etiv_asf', 'mmse']
# Missing: []

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score

oasis1_results = []

for feature_set_name, model_name in BEST_MODELS.items():
    features = FEATURE_SETS[feature_set_name]
    model = trained_models[(feature_set_name, model_name)]

    X_oasis1 = oasis1[features]
    y_oasis1 = oasis1["target"]

    y_pred = model.predict(X_oasis1)
    y_proba = model.predict_proba(X_oasis1)[:, 1]

    oasis1_results.append({
        "feature_set": feature_set_name,
        "model": model_name,
        "oasis1_roc_auc": roc_auc_score(y_oasis1, y_proba),
        "oasis1_accuracy": accuracy_score(y_oasis1, y_pred),
        "oasis1_precision": precision_score(y_oasis1, y_pred, zero_division=0),
        "oasis1_recall": recall_score(y_oasis1, y_pred, zero_division=0),
        "oasis1_f1": f1_score(y_oasis1, y_pred, zero_division=0),
        "n_oasis1": len(oasis1)
    })

oasis1_results_df = pd.DataFrame(oasis1_results)

metric_cols = [
    "oasis1_roc_auc",
    "oasis1_accuracy",
    "oasis1_precision",
    "oasis1_recall",
    "oasis1_f1"
]

oasis1_results_table = oasis1_results_df.copy()
oasis1_results_table[metric_cols] = oasis1_results_table[metric_cols].round(3)

display(oasis1_results_table)

oasis1_results_table.to_csv(
    "../results/oasis1_external_validation_results.csv",
    index=False
)
# Out:
#                            feature_set          model  oasis1_roc_auc  \
# 0                       FS1_accessible        XGBoost           0.629
# 1            FS2_accessible_anatomical        XGBoost           0.775
# 2  FS3_accessible_anatomical_cognitive  Random Forest           0.912
#
#    oasis1_accuracy  oasis1_precision  oasis1_recall  oasis1_f1  n_oasis1
# 0            0.426             0.426           1.00      0.597       235
# 1            0.664             0.567           0.89      0.693       235
# 2            0.830             0.742           0.92      0.821       235

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from pathlib import Path

Path("../results").mkdir(exist_ok=True)

for feature_set_name, model_name in BEST_MODELS.items():
    features = FEATURE_SETS[feature_set_name]
    model = trained_models[(feature_set_name, model_name)]

    X_oasis1 = oasis1[features]
    y_oasis1 = oasis1["target"]

    y_pred = model.predict(X_oasis1)

    cm = confusion_matrix(y_oasis1, y_pred)

    disp = ConfusionMatrixDisplay(
        confusion_matrix=cm,
        display_labels=["Nondemented", "Demented/Impaired"]
    )

    disp.plot()
    plt.title(f"OASIS-1 validation: {feature_set_name} - {model_name}")
    plt.tight_layout()

    filename = f"../results/oasis1_confusion_matrix_{feature_set_name}_{model_name}.png"
    filename = filename.replace(" ", "_")

    plt.savefig(filename, dpi=300, bbox_inches="tight")
    plt.show()

# %%
results_dir = Path("../results")

output_files = sorted([file.name for file in results_dir.iterdir()])

print("Saved output files:")
for file in output_files:
    print("-", file)
# Out:
# Saved output files:
# - .ipynb_checkpoints
# - confusion_matrix_FS1_accessible_XGBoost.png
# - confusion_matrix_FS2_accessible_anatomical_XGBoost.png
# - confusion_matrix_FS3_accessible_anatomical_cognitive_Random_Forest.png
# - feature_importance_FS2_accessible_anatomical_XGBoost.png
# - feature_importance_FS3_accessible_anatomical_cognitive_Random_Forest.png
# - feature_importance_fs2_xgboost.csv
# - feature_importance_fs3_random_forest.csv
# - oasis1_confusion_matrix_FS1_accessible_XGBoost.png
# - oasis1_confusion_matrix_FS2_accessible_anatomical_XGBoost.png
# - oasis1_confusion_matrix_FS3_accessible_anatomical_cognitive_Random_Forest.png
# - oasis1_external_validation_results.csv
# - oasis2_fairness_gap_summary.csv
# - oasis2_fairness_results.csv
# - oasis2_repeated_cv_results.csv
# - oasis2_shap_importance.csv
# - oasis2_tuned_model_results.csv
# - shap_importance_FS1_accessible_XGBoost.png
# - shap_importance_FS2_accessible_anatomical_XGBoost.png
# - shap_importance_FS3_accessible_anatomical_cognitive_Random_Forest.png
